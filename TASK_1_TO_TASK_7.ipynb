# %% [markdown]
# Task 1: Conceptual Understanding (TASK DONE AND FILE UPLOADED ALONG WITH THIS FILE IN THE SAME REPOSITORY)

# %% [markdown]
# Task 2 : Build Advanced Preprocessing Function

# %%
import re
from collections import Counter

def preprocess_text(text):
  # Handle empty input
  if not text or not isinstance(text,str):
    return [],""

  # Convert to lowercase
  text = text.lower()

  # Remove URLs
  text = re.sub(r'http\S+|www\S+', '',text)

   # Remove emails
  text = re.sub(r'\S+@\S+', '', text)

  # Remove numbers
  text = re.sub(r'\d+', '',text)

  # Remove special characters (including emojis)
  text = re.sub(r'[^a-z\s]', '', text)

  # Handle repeated characters
  text = re.sub(r'(.)\1{2,}', r'\1', text)

  # Remove extra spaces
  text = re.sub(r'\s+', ' ', text).strip()

  # Tokenization
  tokens = text.split()

  # Remove short tokens
  tokens = [word for word in tokens if len(word)>2 or word in['no','not']]

  # Final cleaned sentence
  cleaned_sentence = ' '.join(tokens)

  return tokens,cleaned_sentence

# %% [markdown]
# Task 3 : Stress Testing

# %%
sentences=[
    "Get 100% FREE access now!!!",
    "I absolutely looooved this product 😍😍",
    "Worst service ever... 0/10",
    "Call me at 9876543210",
    "This is THE best course!!!",
    "Visit https://openai.com now!",
    "Nooooo this is baaad!!!",
    "OK OK OK I got it",
    "Win $$$ now!!! Limited offer!!!",
    "I am not happy with this"
]

for i , s in enumerate(sentences,1):
  tokens , clean = preprocess_text(s)

  print(f"Sentence {i}:")
  print("Original Text  :", s)
  print("Tokens         :",tokens)
  print("Clean Sentence :",clean)
  print("-" *60)
# Out:
# Sentence 1:
# Original Text  : Get 100% FREE access now!!!
# Tokens         : ['get', 'free', 'access', 'now']
# Clean Sentence : get free access now
# ------------------------------------------------------------
# Sentence 2:
# Original Text  : I absolutely looooved this product 😍😍
# Tokens         : ['absolutely', 'loved', 'this', 'product']
# Clean Sentence : absolutely loved this product
# ------------------------------------------------------------
# Sentence 3:
# Original Text  : Worst service ever... 0/10
# Tokens         : ['worst', 'service', 'ever']
# Clean Sentence : worst service ever
# ------------------------------------------------------------
# Sentence 4:
# Original Text  : Call me at 9876543210
# Tokens         : ['call']
# Clean Sentence : call
# ------------------------------------------------------------
# Sentence 5:
# Original Text  : This is THE best course!!!
# Tokens         : ['this', 'the', 'best', 'course']
# Clean Sentence : this the best course
# ...

# %% [markdown]
# Task 4 : Token Analytics

# %%
from enum import unique
for i , s in enumerate(sentences,1):
  tokens , clean = preprocess_text(s)

  if tokens:
    total = len(tokens)
    unique = len(set(tokens))
    avg_len = sum(len(word) for word in tokens)/total
  else:
    total , unique , avg_len = 0,0,0

  print(f"Sentence {i}:")
  print("Clean Sentence :",clean)
  print("Total Tokens   :",total)
  print("Unique Tokens  :",unique)
  print("Average Length :",round(avg_len,2))
  print("-" *60)
# Out:
# Sentence 1:
# Clean Sentence : get free access now
# Total Tokens   : 4
# Unique Tokens  : 4
# Average Length : 4.0
# ------------------------------------------------------------
# Sentence 2:
# Clean Sentence : absolutely loved this product
# Total Tokens   : 4
# Unique Tokens  : 4
# Average Length : 6.5
# ------------------------------------------------------------
# Sentence 3:
# Clean Sentence : worst service ever
# Total Tokens   : 3
# Unique Tokens  : 3
# Average Length : 5.33
# ------------------------------------------------------------
# Sentence 4:
# Clean Sentence : call
# Total Tokens   : 1
# Unique Tokens  : 1
# Average Length : 4.0
# ------------------------------------------------------------
# Sentence 5:
# Clean Sentence : this the best course
# Total Tokens   : 4
# Unique Tokens  : 4
# Average Length : 4.25
# ------------------------------------------------------------
# Sentence 6:
# Clean Sentence : visit now
# Total Tokens   : 2
# Unique Tokens  : 2
# ...

# %% [markdown]
# Analysis Questions
#
#
# 1. Which sentence had the most noise?
#
# **ANS** : The sentence "Get 100% FREE access now!!!" contains the highest level of noise. This is because it includes multiple forms of unstructured and irrelevant elements such as numerical value,excessive punctuation and inconsistent casing.
# During preprocessing, a significant portion of this sentence is removed or normalized, indicating a high degree of noise.
#
#
# 2. Which sentence retained the most meaningful tokens after cleaning?
#
# **ANS** : The sentence "I am not happy with this" retains the most meaningful tokens after preprocessing. This is because it preserves semantically important words such as "not" and "happy", which is important for understanding sentiment.

# %% [markdown]
# Task : 5 Frequency Analysis

# %%
all_tokens = []

for s in sentences:
  tokens, _ = preprocess_text(s)
  all_tokens.extend(tokens)

from collections import Counter

counter = Counter(all_tokens)
print("Top 10 Frequent Words:")
print(counter.most_common(10))

print("\nLeast 5 Frequent Words:")
print(counter.most_common()[-5:])
# Out:
# Top 10 Frequent Words:
# [('this', 4), ('now', 3), ('get', 1), ('free', 1), ('access', 1), ('absolutely', 1), ('loved', 1), ('product', 1), ('worst', 1), ('service', 1)]
#
# Least 5 Frequent Words:
# [('limited', 1), ('offer', 1), ('not', 1), ('happy', 1), ('with', 1)]

# %% [markdown]
# Task : 6 Full Pipeline Implementation

# %%
def full_pipeline(text_list):
  all_tokens = []
  clean_sentences = []

  for text in text_list:
    tokens, clean = preprocess_text(text)
    all_tokens.extend(tokens)
    clean_sentences.append(clean)
  return {
      "tokens":all_tokens,
      "clean_sentences":clean_sentences
  }

result = full_pipeline(sentences)
print("All Tokens:")
print(result["tokens"])
print("\nClean Sentences:")
print(result["clean_sentences"])
# Out:
# All Tokens:
# ['get', 'free', 'access', 'now', 'absolutely', 'loved', 'this', 'product', 'worst', 'service', 'ever', 'call', 'this', 'the', 'best', 'course', 'visit', 'now', 'no', 'this', 'bad', 'got', 'win', 'now', 'limited', 'offer', 'not', 'happy', 'with', 'this']
#
# Clean Sentences:
# ['get free access now', 'absolutely loved this product', 'worst service ever', 'call', 'this the best course', 'visit now', 'no this bad', 'got', 'win now limited offer', 'not happy with this']

# %% [markdown]
# Task : 7 Error Handling

# %%
test_cases = ["","😍😍🔥","123456"]
for t in test_cases:
  tokens , clean = preprocess_text(t)
  print("Input :",t)
  print("Tokens: ",tokens)
  print("Cleaned: ",clean)
  print("-"*40)
# Out:
# Input :
# Tokens:  []
# Cleaned:
# ----------------------------------------
# Input : 😍😍🔥
# Tokens:  []
# Cleaned:
# ----------------------------------------
# Input : 123456
# Tokens:  []
# Cleaned:
# ----------------------------------------
